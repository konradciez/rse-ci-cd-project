# %%
pip install -i https://test.pypi.org/simple/ rse-ci-cd-project
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# ...

# %%
from src.core import fast_sum_squares, calculate_kinetic_energy
print(f"Suma kwadratów: {fast_sum_squares(10000)}")
print(f"Energia: {calculate_kinetic_energy(10, 5)}")
# Out:
# Suma kwadratów: 333283335000.0
# Energia: 125.0 joule
